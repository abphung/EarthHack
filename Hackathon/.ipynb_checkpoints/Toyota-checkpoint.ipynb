# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from scipy.interpolate import spline

# %%
t1 = pd.read_csv("Trip 1 - 20170303/20170303_sec.csv")
t2 = pd.read_csv("Trip 2 - 20170307/20170307_sec.csv")
t3 = pd.read_csv("Trip 3 - 20170308/20170308_sec.csv")
t4 = pd.read_csv("Trip 4 - 20170309/20170309_sec.csv")
t5 = pd.read_csv("Trip 5 - 20170407/20170407_sec.csv")
ts = [t1, t2, t3, t4, t5]
t1 = t1.fillna(t1.mean())
t2 = t2.fillna(t2.mean())
t3 = t3.fillna(t3.mean())
t4 = t4.fillna(t4.mean())
t5 = t5.fillna(t5.mean())

# %%
t1.head()
# Out:
#                gpsDate   latitude   longitude  Power_Mode  Fuel_Consum  \
# 0  2017-03-03T14:05:06  33.639271 -112.227554         0.0       0.5265
# 1  2017-03-03T14:05:07  33.639271 -112.227556         0.0       0.5265
# 2  2017-03-03T14:05:08  33.639273 -112.227559         0.0       0.5300
# 3  2017-03-03T14:05:09  33.639275 -112.227559         0.0       0.5310
# 4  2017-03-03T14:05:10  33.639275 -112.227561         0.0       0.5320
#
#    GD_Engine_Temp  Steering_Angle_Speed  Transmission_Type  Vehicle_Speed  \
# 0           999.0                 999.0                3.0            0.0
# 1           999.0                 999.0                3.0            0.0
# 2           999.0                 999.0                3.0            0.0
# 3           999.0                 999.0                3.0            0.0
# 4           999.0                 999.0                3.0            0.0
#
#    Engine_Speed        ...         RR_Window_State  Driver_Window_State  \
# 0    1292.96875        ...                     2.0             2.000000
# 1    1294.53125        ...                     2.0             1.926829
# 2    1298.43750        ...                     2.0             1.926829
# 3    1294.53125        ...                     2.0             1.926829
# 4    1297.65625        ...                     2.0             1.926829
#
#    RL_Window_State   AccelFB   AccelLR  Inlet_Switch_Indicator  \
# 0              2.0  0.071810  0.071810                0.454545
# 1              2.0 -0.101512 -0.101512                0.454545
# 2              2.0  0.071810  0.071810                0.000000
# 3              2.0 -0.101512 -0.101512                0.454545
# 4              2.0  0.071810  0.071810                0.454545
#
#    AC_Blower_Level  WhilteLine_Left  LKA_Steering_Support  WhilteLine_Right
# 0         2.181818         2.000000              0.000000          2.000000
# 1         2.181818         2.000000              0.000000          2.000000
# 2         3.000000         1.172161              0.521638          1.170418
# 3         2.181818         2.000000              0.000000          2.000000
# 4         2.181818         1.172161              0.521638          1.170418
#
# [5 rows x 34 columns]

# %%
def plot_cons(df):
    plt.plot(df['Fuel_Consum'].rolling(window = 120).mean())
    plt.show()
    
def plot_loc(df):
    plt.plot(df['longitude'], df['latitude'])
    plt.show()
    
def plot_acc(df):
    df['AccelFB'].rolling(window = 100).mean().plot()
    plt.show()
    
def plot_vel(df):
    df['Vehicle_Speed'].plot()
    plt.show()
    
def plot_fuel(df):
    df['Fuel_Gauge'].rolling(window = 120).mean().plot()
    plt.show()
    
def plot_break(df):
    df['Brake_Control_Volume'].rolling(window = 120).mean().plot()
    plt.show()

# %%
plot_break(t1)

# %%
plot_acc(t1)

# %%
plot_vel(t1)

# %%
plot_fuel(t1)

# %%
t1.corr()
# Out:
#                         latitude  longitude  Power_Mode  Fuel_Consum  \
# latitude                1.000000  -0.900864         NaN    -0.294489
# longitude              -0.900864   1.000000         NaN     0.302928
# Power_Mode                   NaN        NaN         NaN          NaN
# Fuel_Consum            -0.294489   0.302928         NaN     1.000000
# GD_Engine_Temp               NaN        NaN         NaN          NaN
# Steering_Angle_Speed         NaN        NaN         NaN          NaN
# Transmission_Type            NaN        NaN         NaN          NaN
# Vehicle_Speed          -0.306311   0.294690         NaN     0.578998
# Engine_Speed           -0.298272   0.326558         NaN     0.919845
# Brake_Control_Volume    0.021373  -0.034108         NaN    -0.139851
# Radar_Cruise_State           NaN        NaN         NaN          NaN
# Streering_Angle_Degree  0.117999  -0.207080         NaN    -0.105609
# Odometer_Reading        0.896704  -0.999579         NaN    -0.302518
# Hood_Courtesy                NaN        NaN         NaN          NaN
# Passenger_AC_Value     -0.150924   0.268324         NaN     0.174708
# Driver_AC_Value              NaN        NaN         NaN          NaN
# Fuel_Gauge             -0.675811   0.668839         NaN     0.427520
# Rear_Fog_Light               NaN        NaN         NaN          NaN
# Front_Fog_Light        -0.185018   0.332084         NaN     0.267137
# Lounge_Illum_Light      0.022046   0.022931         NaN    -0.283719
# Front_Dome_Light        0.092854  -0.138890         NaN    -0.222296
# Slide_Roof                   NaN        NaN         NaN          NaN
# Passenger_Window_State -0.105474  -0.066701         NaN    -0.265961
# RR_Window_State              NaN        NaN         NaN          NaN
# Driver_Window_State     0.174078  -0.107823         NaN     0.103664
# RL_Window_State              NaN        NaN         NaN          NaN
# AccelFB                -0.020022   0.019117         NaN     0.496474
# AccelLR                -0.020022   0.019117         NaN     0.496474
# Inlet_Switch_Indicator  0.658679  -0.722310         NaN    -0.188135
# AC_Blower_Level        -0.302547   0.160540         NaN    -0.540765
# WhilteLine_Left         0.186078  -0.180635         NaN    -0.396064
# LKA_Steering_Support   -0.365776   0.311619         NaN     0.364564
# WhilteLine_Right        0.175002  -0.177552         NaN    -0.414376
#
#                         GD_Engine_Temp  Steering_Angle_Speed  \
# latitude                           NaN                   NaN
# longitude                          NaN                   NaN
# Power_Mode                         NaN                   NaN
# Fuel_Consum                        NaN                   NaN
# GD_Engine_Temp                     NaN                   NaN
# Steering_Angle_Speed               NaN                   NaN
# Transmission_Type                  NaN                   NaN
# Vehicle_Speed                      NaN                   NaN
# Engine_Speed                       NaN                   NaN
# Brake_Control_Volume               NaN                   NaN
# Radar_Cruise_State                 NaN                   NaN
# Streering_Angle_Degree             NaN                   NaN
# Odometer_Reading                   NaN                   NaN
# Hood_Courtesy                      NaN                   NaN
# Passenger_AC_Value                 NaN                   NaN
# Driver_AC_Value                    NaN                   NaN
# Fuel_Gauge                         NaN                   NaN
# Rear_Fog_Light                     NaN                   NaN
# Front_Fog_Light                    NaN                   NaN
# Lounge_Illum_Light                 NaN                   NaN
# Front_Dome_Light                   NaN                   NaN
# Slide_Roof                         NaN                   NaN
# Passenger_Window_State             NaN                   NaN
# RR_Window_State                    NaN                   NaN
# Driver_Window_State                NaN                   NaN
# RL_Window_State                    NaN                   NaN
# AccelFB                            NaN                   NaN
# AccelLR                            NaN                   NaN
# Inlet_Switch_Indicator             NaN                   NaN
# AC_Blower_Level                    NaN                   NaN
# WhilteLine_Left                    NaN                   NaN
# LKA_Steering_Support               NaN                   NaN
# WhilteLine_Right                   NaN                   NaN
#
#                         Transmission_Type  Vehicle_Speed  Engine_Speed  \
# latitude                              NaN      -0.306311     -0.298272
# longitude                             NaN       0.294690      0.326558
# Power_Mode                            NaN            NaN           NaN
# Fuel_Consum                           NaN       0.578998      0.919845
# GD_Engine_Temp                        NaN            NaN           NaN
# Steering_Angle_Speed                  NaN            NaN           NaN
# Transmission_Type                     NaN            NaN           NaN
# Vehicle_Speed                         NaN       1.000000      0.714575
# Engine_Speed                          NaN       0.714575      1.000000
# Brake_Control_Volume                  NaN      -0.247991     -0.200374
# Radar_Cruise_State                    NaN            NaN           NaN
# Streering_Angle_Degree                NaN      -0.168187     -0.166510
# Odometer_Reading                      NaN      -0.298641     -0.326179
# Hood_Courtesy                         NaN            NaN           NaN
# Passenger_AC_Value                    NaN       0.344822      0.246510
# Driver_AC_Value                       NaN            NaN           NaN
# Fuel_Gauge                            NaN       0.483257      0.447908
# Rear_Fog_Light                        NaN            NaN           NaN
# Front_Fog_Light                       NaN       0.487794      0.376117
# Lounge_Illum_Light                    NaN      -0.533966     -0.333929
# Front_Dome_Light                      NaN      -0.400447     -0.287926
# Slide_Roof                            NaN            NaN           NaN
# Passenger_Window_State                NaN      -0.568593     -0.306160
# RR_Window_State                       NaN            NaN           NaN
# Driver_Window_State                   NaN       0.113504      0.143416
# RL_Window_State                       NaN            NaN           NaN
# AccelFB                               NaN       0.052666      0.430106
# AccelLR                               NaN       0.052666      0.430106
# Inlet_Switch_Indicator                NaN      -0.075676     -0.228408
# AC_Blower_Level                       NaN      -0.744836     -0.600135
# WhilteLine_Left                       NaN      -0.800013     -0.532858
# LKA_Steering_Support                  NaN       0.546330      0.408089
# WhilteLine_Right                      NaN      -0.818455     -0.553612
#
#                         Brake_Control_Volume        ...         \
# latitude                            0.021373        ...
# longitude                          -0.034108        ...
# Power_Mode                               NaN        ...
# Fuel_Consum                        -0.139851        ...
# GD_Engine_Temp                           NaN        ...
# Steering_Angle_Speed                     NaN        ...
# Transmission_Type                        NaN        ...
# Vehicle_Speed                      -0.247991        ...
# Engine_Speed                       -0.200374        ...
# Brake_Control_Volume                1.000000        ...
# Radar_Cruise_State                       NaN        ...
# Streering_Angle_Degree             -0.025902        ...
# Odometer_Reading                    0.032874        ...
# Hood_Courtesy                            NaN        ...
# Passenger_AC_Value                 -0.389425        ...
# Driver_AC_Value                          NaN        ...
# Fuel_Gauge                         -0.028540        ...
# Rear_Fog_Light                           NaN        ...
# Front_Fog_Light                    -0.267176        ...
# Lounge_Illum_Light                 -0.035287        ...
# Front_Dome_Light                   -0.024019        ...
# Slide_Roof                               NaN        ...
# Passenger_Window_State              0.144962        ...
# RR_Window_State                          NaN        ...
# Driver_Window_State                -0.431682        ...
# RL_Window_State                          NaN        ...
# AccelFB                            -0.158156        ...
# AccelLR                            -0.158156        ...
# Inlet_Switch_Indicator             -0.288675        ...
# AC_Blower_Level                     0.217009        ...
# WhilteLine_Left                     0.218372        ...
# LKA_Steering_Support               -0.086709        ...
# WhilteLine_Right                    0.220193        ...
#
#                         RR_Window_State  Driver_Window_State  RL_Window_State  \
# latitude                            NaN             0.174078              NaN
# longitude                           NaN            -0.107823              NaN
# Power_Mode                          NaN                  NaN              NaN
# Fuel_Consum                         NaN             0.103664              NaN
# GD_Engine_Temp                      NaN                  NaN              NaN
# Steering_Angle_Speed                NaN                  NaN              NaN
# Transmission_Type                   NaN                  NaN              NaN
# Vehicle_Speed                       NaN             0.113504              NaN
# Engine_Speed                        NaN             0.143416              NaN
# Brake_Control_Volume                NaN            -0.431682              NaN
# Radar_Cruise_State                  NaN                  NaN              NaN
# Streering_Angle_Degree              NaN            -0.003308              NaN
# Odometer_Reading                    NaN             0.074172              NaN
# Hood_Courtesy                       NaN                  NaN              NaN
# Passenger_AC_Value                  NaN            -0.125000              NaN
# Driver_AC_Value                     NaN                  NaN              NaN
# Fuel_Gauge                          NaN                  NaN              NaN
# Rear_Fog_Light                      NaN                  NaN              NaN
# Front_Fog_Light                     NaN                  NaN              NaN
# Lounge_Illum_Light                  NaN             0.188982              NaN
# Front_Dome_Light                    NaN             0.133631              NaN
# Slide_Roof                          NaN                  NaN              NaN
# Passenger_Window_State              NaN            -0.116335              NaN
# RR_Window_State                     NaN                  NaN              NaN
# Driver_Window_State                 NaN             1.000000              NaN
# RL_Window_State                     NaN                  NaN              NaN
# AccelFB                             NaN             0.770013              NaN
# AccelLR                             NaN             0.770013              NaN
# Inlet_Switch_Indicator              NaN                  NaN              NaN
# AC_Blower_Level                     NaN                  NaN              NaN
# WhilteLine_Left                     NaN            -0.225374              NaN
# LKA_Steering_Support                NaN             0.095238              NaN
# WhilteLine_Right                    NaN            -0.183340              NaN
#
#                          AccelFB   AccelLR  Inlet_Switch_Indicator  \
# latitude               -0.020022 -0.020022                0.658679
# longitude               0.019117  0.019117               -0.722310
# Power_Mode                   NaN       NaN                     NaN
# Fuel_Consum             0.496474  0.496474               -0.188135
# GD_Engine_Temp               NaN       NaN                     NaN
# Steering_Angle_Speed         NaN       NaN                     NaN
# Transmission_Type            NaN       NaN                     NaN
# Vehicle_Speed           0.052666  0.052666               -0.075676
# Engine_Speed            0.430106  0.430106               -0.228408
# Brake_Control_Volume   -0.158156 -0.158156               -0.288675
# Radar_Cruise_State           NaN       NaN                     NaN
# Streering_Angle_Degree  0.076179  0.076179                0.030650
# Odometer_Reading       -0.016960 -0.016960                0.626861
# Hood_Courtesy                NaN       NaN                     NaN
# Passenger_AC_Value      0.031247  0.031247                     NaN
# Driver_AC_Value              NaN       NaN                     NaN
# Fuel_Gauge              0.043247  0.043247                     NaN
# Rear_Fog_Light               NaN       NaN                     NaN
# Front_Fog_Light        -0.014838 -0.014838                     NaN
# Lounge_Illum_Light      0.068818  0.068818                     NaN
# Front_Dome_Light        0.126863  0.126863                     NaN
# Slide_Roof                   NaN       NaN                     NaN
# Passenger_Window_State  0.084080  0.084080                     NaN
# RR_Window_State              NaN       NaN                     NaN
# Driver_Window_State     0.770013  0.770013                     NaN
# RL_Window_State              NaN       NaN                     NaN
# AccelFB                 1.000000  1.000000                0.238987
# AccelLR                 1.000000  1.000000                0.238987
# Inlet_Switch_Indicator  0.238987  0.238987                1.000000
# AC_Blower_Level         0.589793  0.589793                0.013921
# WhilteLine_Left        -0.029799 -0.029799                0.500000
# LKA_Steering_Support    0.051406  0.051406               -0.774597
# WhilteLine_Right       -0.040158 -0.040158                0.500000
#
#                         AC_Blower_Level  WhilteLine_Left  \
# latitude                      -0.302547         0.186078
# longitude                      0.160540        -0.180635
# Power_Mode                          NaN              NaN
# Fuel_Consum                   -0.540765        -0.396064
# GD_Engine_Temp                      NaN              NaN
# Steering_Angle_Speed                NaN              NaN
# Transmission_Type                   NaN              NaN
# Vehicle_Speed                 -0.744836        -0.800013
# Engine_Speed                  -0.600135        -0.532858
# Brake_Control_Volume           0.217009         0.218372
# Radar_Cruise_State                  NaN              NaN
# Streering_Angle_Degree         0.262285         0.142104
# Odometer_Reading              -0.181260         0.191009
# Hood_Courtesy                       NaN              NaN
# Passenger_AC_Value                  NaN        -0.304767
# Driver_AC_Value                     NaN              NaN
# Fuel_Gauge                          NaN        -0.329131
# Rear_Fog_Light                      NaN              NaN
# Front_Fog_Light                     NaN        -0.422586
# Lounge_Illum_Light                  NaN         0.448876
# Front_Dome_Light                    NaN         0.346400
# Slide_Roof                          NaN              NaN
# Passenger_Window_State              NaN         0.422577
# RR_Window_State                     NaN              NaN
# Driver_Window_State                 NaN        -0.225374
# RL_Window_State                     NaN              NaN
# AccelFB                        0.589793        -0.029799
# AccelLR                        0.589793        -0.029799
# Inlet_Switch_Indicator         0.013921         0.500000
# AC_Blower_Level                1.000000         0.689730
# WhilteLine_Left                0.689730         1.000000
# LKA_Steering_Support          -0.483381        -0.464972
# WhilteLine_Right               0.689730         0.749511
#
#                         LKA_Steering_Support  WhilteLine_Right
# latitude                           -0.365776          0.175002
# longitude                           0.311619         -0.177552
# Power_Mode                               NaN               NaN
# Fuel_Consum                         0.364564         -0.414376
# GD_Engine_Temp                           NaN               NaN
# Steering_Angle_Speed                     NaN               NaN
# Transmission_Type                        NaN               NaN
# Vehicle_Speed                       0.546330         -0.818455
# Engine_Speed                        0.408089         -0.553612
# Brake_Control_Volume               -0.086709          0.220193
# Radar_Cruise_State                       NaN               NaN
# Streering_Angle_Degree             -0.070077          0.145039
# Odometer_Reading                   -0.319079          0.186314
# Hood_Courtesy                            NaN               NaN
# Passenger_AC_Value                  0.202300         -0.370545
# Driver_AC_Value                          NaN               NaN
# Fuel_Gauge                          0.608583         -0.334169
# Rear_Fog_Light                           NaN               NaN
# Front_Fog_Light                     0.248726         -0.461776
# Lounge_Illum_Light                 -0.225264          0.444593
# Front_Dome_Light                   -0.173838          0.343095
# Slide_Roof                               NaN               NaN
# Passenger_Window_State              0.095238          0.519462
# RR_Window_State                          NaN               NaN
# Driver_Window_State                 0.095238         -0.183340
# RL_Window_State                          NaN               NaN
# AccelFB                             0.051406         -0.040158
# AccelLR                             0.051406         -0.040158
# Inlet_Switch_Indicator             -0.774597          0.500000
# AC_Blower_Level                    -0.483381          0.689730
# WhilteLine_Left                    -0.464972          0.749511
# LKA_Steering_Support                1.000000         -0.469732
# WhilteLine_Right                   -0.469732          1.000000
#
# [33 rows x 33 columns]

# %%
ser = abs(t1.corr()['Fuel_Consum'].copy(True))
ser.sort_values()
# Out:
# Inlet_Switch_Indicator    0.003457
# Driver_Window_State       0.006117
# AC_Blower_Level           0.009936
# Passenger_Window_State    0.015596
# Passenger_AC_Value        0.065123
# Front_Dome_Light          0.070455
# Front_Fog_Light           0.083193
# Lounge_Illum_Light        0.089923
# Streering_Angle_Degree    0.105444
# Fuel_Gauge                0.121215
# Brake_Control_Volume      0.139828
# Odometer_Reading          0.246288
# latitude                  0.294463
# LKA_Steering_Support      0.299078
# longitude                 0.302895
# WhilteLine_Left           0.324920
# WhilteLine_Right          0.339942
# AccelFB                   0.382884
# AccelLR                   0.382884
# Vehicle_Speed             0.578710
# Engine_Speed              0.919653
# Fuel_Consum               1.000000
# Power_Mode                     NaN
# GD_Engine_Temp                 NaN
# Steering_Angle_Speed           NaN
# Transmission_Type              NaN
# Radar_Cruise_State             NaN
# Hood_Courtesy                  NaN
# Driver_AC_Value                NaN
# Rear_Fog_Light                 NaN
# Slide_Roof                     NaN
# RR_Window_State                NaN
# RL_Window_State                NaN
# Name: Fuel_Consum, dtype: float64

# %%
def gental_acc_score(df):
    #thresh is .25
    return len(df[abs(df['AccelFB']) < .25])/float(len(df['AccelFB']))

def steady_speed_score(df):
    freq = [point if point < 10000 else 10000 for point in abs(np.fft.rfft(df['Vehicle_Speed']))]
    return sum(freq[:len(freq)/4])/sum(freq)

def coast_2_decc_score(df):
    return len(df[abs(df['Brake_Control_Volume']) < .01])/float(len(df['Brake_Control_Volume']))

def high_speed_score(df):
    return len(df[abs(df['Vehicle_Speed']) < 76])/float(len(df['Vehicle_Speed']))

# %%
print gental_acc_score(t1), coast_2_decc_score(t1), high_speed_score(t1), steady_speed_score(t4)
# Out:
# 0.785977154328 0.796874253214 0.734407111791 0.651645328607

# %%
plot_vel(t4)#this is wrong possible becasuse of the way the nan's are being delt with

# %%
plt.plot(np.fft.rfft(t1['Vehicle_Speed']))
plt.show()

# %%
freq = [point if point < 10000 else 10000 for point in abs(np.fft.rfft(t1['Vehicle_Speed']))]
sum(freq[:len(freq)/4])/sum(freq)
plt.plot(freq)
plt.show()

# %%
sum(freq[:len(freq)/4])/sum(freq)
# Out:
# 0.86613322551325067

# %%
def google_plotable(df, name):
    df.iloc[::1 + len(df)/2000, :].to_csv(name)

# %%
google_plotable(t1, "t1.csv")
google_plotable(t2, "t2.csv")
google_plotable(t3, "t3.csv")
google_plotable(t4, "t4.csv")
google_plotable(t5, "t5.csv")

# %%
def barplot_cons(df):
    plt.plot(df['Fuel_Consum'].rolling(window = 120).mean())
    plt.show()
    
def barplot_loc(df):
    plt.plot(df['longitude'], df['latitude'])
    plt.show()
    
def barplot_acc(df):
    df['AccelFB'].rolling(window = 100).mean().plot.bar()
    plt.show()
    
def barplot_vel(df):
    df['Vehicle_Speed'].plot()
    plt.show()
    
def barplot_fuel(df):
    df['Fuel_Gauge'].rolling(window = 120).mean().plot()
    plt.show()
    
def barplot_break(df):
    df['Brake_Control_Volume'].rolling(window = 120).mean().plot()
    plt.show()

# %%
barplot_acc(t1.iloc[::len(df)/100, :])

# %%
print "hi"
